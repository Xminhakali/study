# %% [markdown]
# <a href="https://colab.research.google.com/github/Xminhakali/study/blob/main/AI__W3_17_02_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dataframe.shape
# Out:
# (3, 3)

# %%
df = dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Price    3 non-null      int64
#  2   License  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
#print column name
list(df.columns)
# Out:
# ['Name', 'Price', 'License']

# %%
df.describe()
# Out:
#           Price
# count  3.000000
# mean   6.666667
# std    1.527525
# min    5.000000
# 25%    6.000000
# 50%    7.000000
# 75%    7.500000
# max    8.000000

# %%
# load library
import pandas as pd
# creat dataframe
dataframe = pd.DataFrame()
# add colums
dataframe['Name'] = ['Lemon', 'Apple', 'Banana']
dataframe['Price'] = [5,8,7]
dataframe['License'] = [False,True,False]
#show data
dataframe
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7    False

# %%
df.loc[(df.Price == 5) | (df.Name== 'Banana')]
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 2  Banana      7    False

# %%
#loc iloc truy xuat du lieu
df.loc[(df.Price == 5)]
# Out:
#     Name  Price  License
# 0  Lemon      5    False

# %%
df.iloc[2]
type(df.iloc[2])
# Out:
# pandas.core.series.Series

# %%
df.iloc[[2]] #dday la chuoi sries phai them[]
# Out:
#      Name  Price  License
# 2  Banana      7    False

# %%
df.iloc[0:3] #iloc python se bo gia tri cuoi cung
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7    False

# %%
df.iloc[0:2,0:-1] #bo cot
# Out:
#     Name  Price
# 0  Lemon      5
# 1  Apple      8

# %%
df.iloc[0:2,-1]
# Out:
# 0    False
# 1     True
# Name: License, dtype: bool

# %%
sum= df.Price.sum()
print(sum)
# Out:
# 20

# %%
max = df.Price.max()
print(max)
# Out:
# 8

# %%
count = df['Price'].count()
print(count)
# Out:
# 3

# %%
# creatte row data
new = pd.Series(['Orange',10,True], index=['Name','Price','License'])

#append row
dataframe.append(new, ignore_index= True)
#them gia tri trong hang de xem data thay doi nhu the nao chua chinh sua trong cot
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7    False
# 3  Orange     10     True

# %%
dataframe['Location'] = ['USA','VN','SIN']
dataframe
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 1   Apple      8     True       VN
# 2  Banana      7    False      SIN

# %%
# delete a row xoa hang
dataframe.drop(1, axis=0).head(10) #xoa hang axis=0 co gia tri 1
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 2  Banana      7    False      SIN

# %%
#delete a column
dataframe.drop('Location' , axis=1).head()
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7    False

# %%
#replace
dataframe['Price'].replace(5,7).head(2)
# thay gia tri trong data
#head la hien thi so data
# Out:
# 0    7
# 1    8
# Name: Price, dtype: int64

# %%
#rename columns
dataframe.rename(columns={'Price' :'Cost'}).head()
#thay the gia trij cot
# Out:
#      Name  Cost  License Location
# 0   Lemon     5    False      USA
# 1   Apple     8     True       VN
# 2  Banana     7    False      SIN

# %%
#2. KNOWING DATA

#load library

import pandas as pd 

#creat url

url ='/medals.csv'

#load data
dataframe = pd. read_csv(url)

#show data

dataframe.head()
#file csv= dang bang trong excel.trongpy laf ngan cach boi dau phay.. tsv
# VD doc file tsv
# dataframe= pd.read.csv('url',sep='it')
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
dataframe.shape
# Out:
# (2311, 8)

# %%
df= dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2311 entries, 0 to 2310
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          2311 non-null   int64
#  1   City          2311 non-null   object
#  2   Sport         2311 non-null   object
#  3   Discipline    2311 non-null   object
#  4   NOC           2311 non-null   object
#  5   Event         2311 non-null   object
#  6   Event gender  2311 non-null   object
#  7   Medal         2311 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 144.6+ KB

# %%
list (df.columns)
# Out:
# ['Year',
#  'City',
#  'Sport',
#  'Discipline',
#  'NOC',
#  'Event',
#  'Event gender',
#  'Medal']

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# ...

# %%
df.loc[(df.Medal == 'Gold')]
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 7     1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9     1924  Chamonix     Skating   Speed skating  FIN            1500m
# ...    ...       ...         ...             ...  ...              ...
# 2301  2006     Turin      Skiing   Alpine Skiing  USA  Alpine combined
# 2302  2006     Turin      Skiing   Alpine Skiing  USA     giant slalom
# 2305  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender Medal
# 1               W  Gold
# 2               X  Gold
# 4               M  Gold
# ...

# %%
df.loc[(df.Sport == 'Skiing') | (df.Year == 2006) | (df.NOC == 'USA')]
# Out:
#       Year      City   Sport       Discipline  NOC            Event  \
# 15    1924  Chamonix  Skiing  Cross Country S  FIN             18km
# 30    1924  Chamonix  Skiing  Cross Country S  NOR             18km
# 31    1924  Chamonix  Skiing  Cross Country S  NOR             18km
# 32    1924  Chamonix  Skiing  Cross Country S  NOR             50km
# 33    1924  Chamonix  Skiing  Cross Country S  NOR             50km
# ...    ...       ...     ...              ...  ...              ...
# 2306  2006     Turin  Skiing        Snowboard  USA        Half-pipe
# 2307  2006     Turin  Skiing        Snowboard  USA        Half-pipe
# 2308  2006     Turin  Skiing        Snowboard  USA        Half-pipe
# 2309  2006     Turin  Skiing        Snowboard  USA  Snowboard Cross
# 2310  2006     Turin  Skiing        Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 15              M  Bronze
# 30              M    Gold
# 31              M  Silver
# 32              M  Bronze
# ...

# %%
df.iloc[[2000]] 
df.iloc[0:1001]
# Out:
#       Year         City       Sport       Discipline  NOC       Event  \
# 0     1924     Chamonix     Skating   Figure skating  AUT  individual
# 1     1924     Chamonix     Skating   Figure skating  AUT  individual
# 2     1924     Chamonix     Skating   Figure skating  AUT       pairs
# 3     1924     Chamonix   Bobsleigh        Bobsleigh  BEL    four-man
# 4     1924     Chamonix  Ice Hockey       Ice Hockey  CAN  ice hockey
# ...    ...          ...         ...              ...  ...         ...
# 996   1980  Lake Placid      Skiing  Cross Country S  URS        50km
# 997   1980  Lake Placid      Skiing  Cross Country S  URS        50km
# 998   1980  Lake Placid      Skiing  Cross Country S  URS         5km
# 999   1980  Lake Placid  Ice Hockey       Ice Hockey  USA  ice hockey
# 1000  1980  Lake Placid     Skating   Figure skating  USA  individual
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
df.iloc[[233]]
# Out:
#      Year        City    Sport     Discipline  NOC  Event Event gender   Medal
# 233  1948  St. Moritz  Skating  Speed skating  SWE  5000m            M  Bronze

# %%
df.iloc[0:10,1:-1]
# Out:
#        City       Sport      Discipline  NOC            Event Event gender
# 0  Chamonix     Skating  Figure skating  AUT       individual            M
# 1  Chamonix     Skating  Figure skating  AUT       individual            W
# 2  Chamonix     Skating  Figure skating  AUT            pairs            X
# 3  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man            M
# 4  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey            M
# 5  Chamonix    Biathlon        Biathlon  FIN  military patrol            M
# 6  Chamonix     Skating  Figure skating  FIN            pairs            X
# 7  Chamonix     Skating   Speed skating  FIN           10000m            M
# 8  Chamonix     Skating   Speed skating  FIN           10000m            M
# 9  Chamonix     Skating   Speed skating  FIN            1500m            M

# %%
df.iloc[0:10,-7]
# Out:
# 0    Chamonix
# 1    Chamonix
# 2    Chamonix
# 3    Chamonix
# 4    Chamonix
# 5    Chamonix
# 6    Chamonix
# 7    Chamonix
# 8    Chamonix
# 9    Chamonix
# Name: City, dtype: object

# %%
sum= df.Sport.sum()
print(sum)
# Out:
# SkatingSkatingSkatingBobsleighIce HockeyBiathlonSkatingSkatingSkatingSkatingSkatingSkatingSkatingSkatingSkatingSkiingBiathlonCurlingSkatingBobsleighCurlingIce HockeySkatingSkatingSkatingSkatingSkatingSkatingSkatingSkatingSkiingSkiingSkiingSkiingSkiingSkiingSkiingSkiingSkiingSkiingBiathlonBobsleighSkatingCurlingSkatingIce HockeySkatingSkatingSkiingSkatingSkatingSkatingSkatingSkatingIce HockeySkatingSkatingSkatingSkatingSkatingBobsleighBobsleighSkatingSkatingSkatingSkatingSkatingSkatingSkatingSkiingSkiingSkiingSkiingSkiingSkiingSkiingSkiingIce HockeyIce HockeySkatingSkiingSkiingSkiingSkiingBobsleighBobsleighBobsleighBobsleighSkatingSkatingSkatingSkatingIce HockeySkatingSkatingSkatingSkatingSkatingSkatingSkiingSkiingSkiingSkatingBobsleighIce HockeySkatingSkatingSkatingSkatingSkiingSkiingSkiingSkiingSkiingSkiingSkiingBobsleighSkatingSkiingSkiingBobsleighBobsleighBobsleighBobsleighIce HockeySkatingSkatingSkatingSkatingSkatingSkatingSkatingSkatingSkatingSkatingSkatingIce HockeySkatingSkati
# ...

# %%
max = df.Medal.max()
print(max)
# Out:
# Silver

# %%
# cac Vd moi

# %%
data= dataframe
data.shape
# Out:
# (2311, 8)

# %%
data.describe()
#std: phuong sai
#mean: gia tri tb
# Out:
#               Year
# count  2311.000000
# mean   1980.361748
# std      22.089091
# min    1924.000000
# 25%    1968.000000
# 50%    1988.000000
# 75%    1998.000000
# max    2006.000000

# %%
data.iloc[0:11]
# Out:
#     Year      City       Sport      Discipline  NOC            Event  \
# 0   1924  Chamonix     Skating  Figure skating  AUT       individual
# 1   1924  Chamonix     Skating  Figure skating  AUT       individual
# 2   1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3   1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4   1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 5   1924  Chamonix    Biathlon        Biathlon  FIN  military patrol
# 6   1924  Chamonix     Skating  Figure skating  FIN            pairs
# 7   1924  Chamonix     Skating   Speed skating  FIN           10000m
# 8   1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9   1924  Chamonix     Skating   Speed skating  FIN            1500m
# 10  1924  Chamonix     Skating   Speed skating  FIN            5000m
#
#    Event gender   Medal
# 0             M  Silver
# 1             W    Gold
# 2             X    Gold
# 3             M  Bronze
# ...

# %%
data.iloc[[200]]
# Out:
#      Year        City   Sport       Discipline  NOC       Event Event gender  \
# 200  1948  St. Moritz  Skiing  Nordic Combined  FIN  individual            M
#
#     Medal
# 200  Gold

# %%
data= data.set_index(data['Medal'])
data.loc['Gold']
# Out:
#        Year      City       Sport      Discipline  NOC            Event  \
# Medal
# Gold   1924  Chamonix     Skating  Figure skating  AUT       individual
# Gold   1924  Chamonix     Skating  Figure skating  AUT            pairs
# Gold   1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# Gold   1924  Chamonix     Skating   Speed skating  FIN           10000m
# Gold   1924  Chamonix     Skating   Speed skating  FIN            1500m
# ...     ...       ...         ...             ...  ...              ...
# Gold   2006     Turin      Skiing   Alpine Skiing  USA  Alpine combined
# Gold   2006     Turin      Skiing   Alpine Skiing  USA     giant slalom
# Gold   2006     Turin      Skiing       Snowboard  USA        Half-pipe
# Gold   2006     Turin      Skiing       Snowboard  USA        Half-pipe
# Gold   2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#       Event gender Medal
# Medal
# Gold             W  Gold
# Gold             X  Gold
# ...

# %%
data.loc['Silver']
# Out:
#         Year      City     Sport      Discipline  NOC            Event  \
# Medal
# Silver  1924  Chamonix   Skating  Figure skating  AUT       individual
# Silver  1924  Chamonix  Biathlon        Biathlon  FIN  military patrol
# Silver  1924  Chamonix   Skating  Figure skating  FIN            pairs
# Silver  1924  Chamonix   Skating   Speed skating  FIN           10000m
# Silver  1924  Chamonix   Skating   Speed skating  FIN            5000m
# ...      ...       ...       ...             ...  ...              ...
# Silver  2006     Turin   Skating   Speed skating  USA            1000m
# Silver  2006     Turin   Skating   Speed skating  USA            1500m
# Silver  2006     Turin    Skiing       Snowboard  USA        Half-pipe
# Silver  2006     Turin    Skiing       Snowboard  USA        Half-pipe
# Silver  2006     Turin    Skiing       Snowboard  USA  Snowboard Cross
#
#        Event gender   Medal
# Medal
# Silver            M  Silver
# Silver            M  Silver
# ...

# %%
data[data['NOC']=='CAN'].head()
# Out:
#         Year         City       Sport      Discipline  NOC       Event  \
# Medal
# Gold    1924     Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey
# Gold    1928   St. Moritz  Ice Hockey      Ice Hockey  CAN  ice hockey
# Gold    1932  Lake Placid  Ice Hockey      Ice Hockey  CAN  ice hockey
# Bronze  1932  Lake Placid     Skating  Figure skating  CAN  individual
# Bronze  1932  Lake Placid     Skating   Speed skating  CAN      10000m
#
#        Event gender   Medal
# Medal
# Gold              M    Gold
# Gold              M    Gold
# Gold              M    Gold
# Bronze            M  Bronze
# Bronze            M  Bronze

# %%
data[(data['Year']>=1932)&(data["Year"]<=2000) & (data['Sport']=='Skating') & (data['NOC']== 'CAN')].head()
# Out:
#         Year         City    Sport      Discipline  NOC       Event  \
# Medal
# Bronze  1932  Lake Placid  Skating  Figure skating  CAN  individual
# Bronze  1932  Lake Placid  Skating   Speed skating  CAN      10000m
# Bronze  1932  Lake Placid  Skating   Speed skating  CAN       1500m
# Silver  1932  Lake Placid  Skating   Speed skating  CAN       1500m
# Bronze  1932  Lake Placid  Skating   Speed skating  CAN       5000m
#
#        Event gender   Medal
# Medal
# Bronze            M  Bronze
# Bronze            M  Bronze
# Bronze            M  Bronze
# Silver            M  Silver
# Bronze            M  Bronze

# %%
data['NOC'].value_counts()
# Out:
# NOR    280
# USA    216
# URS    194
# AUT    185
# GER    158
# FIN    151
# CAN    119
# SUI    118
# SWE    118
# GDR    110
# ITA    101
# FRA     83
# NED     78
# RUS     76
# FRG     41
# CHN     33
# JPN     32
# KOR     31
# TCH     25
# EUN     23
# GBR     21
# EUA     19
# CZE     10
# LIE      9
# POL      8
# CRO      7
# BUL      6
# EST      6
# AUS      6
# BLR      6
# HUN      6
# UKR      5
# BEL      5
# KAZ      5
# YUG      4
# SLO      4
# ESP      2
# PRK      2
# LUX      2
# LAT      1
# ROU      1
# DEN      1
# UZB      1
# NZL      1
# SVK      1
# Name: NOC, dtype: int64

# %%
data.count()
# Out:
# Year            2311
# City            2311
# Sport           2311
# Discipline      2311
# NOC             2311
# Event           2311
# Event gender    2311
# Medal           2311
# dtype: int64

# %%
data['Medal'].count()
# Out:
# 2311

# %%
data['Year'].unique()
# Out:
# array([1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968, 1972,
#        1976, 1980, 1984, 1988, 1992, 1994, 1998, 2002, 2006])

# %%
data.drop('NOC',axis=1).head(30)
# Out:
#         Year      City       Sport       Discipline                Event  \
# Medal
# Silver  1924  Chamonix     Skating   Figure skating           individual
# Gold    1924  Chamonix     Skating   Figure skating           individual
# Gold    1924  Chamonix     Skating   Figure skating                pairs
# Bronze  1924  Chamonix   Bobsleigh        Bobsleigh             four-man
# Gold    1924  Chamonix  Ice Hockey       Ice Hockey           ice hockey
# Silver  1924  Chamonix    Biathlon         Biathlon      military patrol
# Silver  1924  Chamonix     Skating   Figure skating                pairs
# Gold    1924  Chamonix     Skating    Speed skating               10000m
# Silver  1924  Chamonix     Skating    Speed skating               10000m
# Gold    1924  Chamonix     Skating    Speed skating                1500m
# Gold    1924  Chamonix     Skating    Speed skating                5000m
# Silver  1924  Chamonix     Skating    Speed skating                5000m
# ...

# %%
data.drop(data.columns[2:4],axis=1).head()
# Out:
#         Year      City  NOC       Event Event gender   Medal
# Medal
# Silver  1924  Chamonix  AUT  individual            M  Silver
# Gold    1924  Chamonix  AUT  individual            W    Gold
# Gold    1924  Chamonix  AUT       pairs            X    Gold
# Bronze  1924  Chamonix  BEL    four-man            M  Bronze
# Gold    1924  Chamonix  CAN  ice hockey            M    Gold

# %%
data[data['Year']!='2006'].head()
# Out:
#         Year      City       Sport      Discipline  NOC       Event  \
# Medal
# Silver  1924  Chamonix     Skating  Figure skating  AUT  individual
# Gold    1924  Chamonix     Skating  Figure skating  AUT  individual
# Gold    1924  Chamonix     Skating  Figure skating  AUT       pairs
# Bronze  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man
# Gold    1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey
#
#        Event gender   Medal
# Medal
# Silver            M  Silver
# Gold              W    Gold
# Gold              X    Gold
# Bronze            M  Bronze
# Gold              M    Gold

# %%
data=pd.read_csv(url)
data.groupby('NOC').head(10)
# Out:
#       Year      City       Sport       Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating   Figure skating  AUT       individual
# 1     1924  Chamonix     Skating   Figure skating  AUT       individual
# 2     1924  Chamonix     Skating   Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh        Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey       Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...              ...  ...              ...
# 2231  2006     Turin    Biathlon         Biathlon  POL  15km mass start
# 2232  2006     Turin      Skiing  Cross Country S  POL             30km
# 2269  2006     Turin      Skiing        Snowboard  SVK  Snowboard Cross
# 2284  2006     Turin    Biathlon         Biathlon  UKR            7.5km
# 2285  2006     Turin     Skating   Figure skating  UKR      ice dancing
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# ...

# %%
data.groupby('NOC').count()
# Out:
#      Year  City  Sport  Discipline  Event  Event gender  Medal
# NOC
# AUS     6     6      6           6      6             6      6
# AUT   185   185    185         185    185           185    185
# BEL     5     5      5           5      5             5      5
# BLR     6     6      6           6      6             6      6
# BUL     6     6      6           6      6             6      6
# CAN   119   119    119         119    119           119    119
# CHN    33    33     33          33     33            33     33
# CRO     7     7      7           7      7             7      7
# CZE    10    10     10          10     10            10     10
# DEN     1     1      1           1      1             1      1
# ESP     2     2      2           2      2             2      2
# EST     6     6      6           6      6             6      6
# EUA    19    19     19          19     19            19     19
# EUN    23    23     23          23     23            23     23
# ...

# %%
data.groupby(['Year','NOC']).head()
# Out:
#       Year      City       Sport      Discipline  NOC        Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT   individual
# 1     1924  Chamonix     Skating  Figure skating  AUT   individual
# 2     1924  Chamonix     Skating  Figure skating  AUT        pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL     four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN   ice hockey
# ...    ...       ...         ...             ...  ...          ...
# 2286  2006     Turin   Bobsleigh       Bobsleigh  USA      two-man
# 2287  2006     Turin     Curling         Curling  USA      curling
# 2288  2006     Turin  Ice Hockey      Ice Hockey  USA   ice hockey
# 2289  2006     Turin     Skating  Figure skating  USA  ice dancing
# 2290  2006     Turin     Skating  Figure skating  USA   individual
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# 3               M  Bronze
# ...

# %%
data.groupby(['Year','NOC']).count()
# Out:
#           City  Sport  Discipline  Event  Event gender  Medal
# Year NOC
# 1924 AUT     3      3           3      3             3      3
#      BEL     1      1           1      1             1      1
#      CAN     1      1           1      1             1      1
#      FIN    11     11          11     11            11     11
#      FRA     3      3           3      3             3      3
# ...        ...    ...         ...    ...           ...    ...
# 2006 SUI    14     14          14     14            14     14
#      SVK     1      1           1      1             1      1
#      SWE    14     14          14     14            14     14
#      UKR     2      2           2      2             2      2
#      USA    25     25          25     25            25     25
#
# [328 rows x 6 columns]

# %%
#
